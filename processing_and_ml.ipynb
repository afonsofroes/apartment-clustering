# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# %%
jan_apr = pd.read_csv('dados_afonso/room_say_report/reservas_por_data_criada/jan_apr.csv')
may_june = pd.read_csv('dados_afonso/room_say_report/reservas_por_data_criada/may_june.csv')
jul_aug = pd.read_csv('dados_afonso/room_say_report/reservas_por_data_criada/jul_aug.csv')

data = pd.concat([jan_apr, may_june, jul_aug])

# %% [markdown]
# # Make new columns

# %%
data.head()
# Out:
#   Reservation ID      Channel Affiliated Channel            Booked At  \
# 0     2468606756  Booking.com                NaN  2022-01-01 13:19:36
# 1     3404160971  Booking.com                NaN  2022-01-02 21:57:44
# 2     3545920362  Booking.com                NaN  2022-01-03 02:29:23
# 3     3807966157  Booking.com                NaN  2022-01-03 17:48:12
# 4     2769935846  Booking.com                NaN  2022-01-01 22:51:52
#
#   Modified At Cancelled At                                               Room  \
# 0         NaN          NaN  Apartamento - Piso Térreo - 24% - Oferta InÃ­c...
# 1         NaN          NaN  Apartamento com 1 Quarto (2 Adultos) - Rua dos...
# 2         NaN          NaN  Apartamento com 1 Quarto - Rua de Santo Estêvã...
# 3         NaN          NaN   Apartamento - Piso Térreo - High Season 3 Nights
# 4         NaN          NaN  Apartamento com 2 Quartos (4 Adultos) - Rua do...
#
#      Check-In   Check-Out             Guests  Adults  Children  Infants
# 0  2022-01-02  2022-01-03   B****** C*******       2       NaN      NaN
# 1  2022-01-03  2022-01-05     M***** K******       2       NaN      NaN
# 2  2022-01-03  2022-01-09    S****** M******       1       NaN      NaN
# 3  2022-01-03  2022-01-06      W****** C****       2       NaN      NaN
# 4  2022-01-03  2022-01-08  , S***** N*******       2       1.0      NaN

# %%
data['Booked At'] = pd.to_datetime(data['Booked At'], format='%Y/%m/%d %H:%M:%S')
data['Booked At'] = data['Booked At'].dt.date
data['Booked At'] = pd.to_datetime(data['Booked At'], format='%Y/%m/%d')
data['Check-In'] = pd.to_datetime(data['Check-In'], format='%Y/%m/%d')
data['Check-Out'] = pd.to_datetime(data['Check-Out'], format='%Y/%m/%d')
data['Cancelled At'] = pd.to_datetime(data['Cancelled At'], format='%Y/%m/%d %H:%M:%S')
data['Cancelled At'] = data['Cancelled At'].dt.date
data['Cancelled At'] = pd.to_datetime(data['Cancelled At'], format='%Y/%m/%d')

# %%
data['days_ahead'] = data['Check-In'] - data['Booked At']
data['days_ahead'] = data['days_ahead'].dt.days

# %%
data['discounted'] = data['Room'].str.find('%') != -1
data['discounted'] = data['discounted'].astype(int)

# %%
data['stay'] = data['Check-Out'] - data['Check-In']
data['stay'] = data['stay'].dt.days

# %%
data['canceled_after_booking'] = data['Cancelled At'] - data['Booked At']
data['canceled_after_booking'] = data['canceled_after_booking'].dt.days

# %%
data['modified'] = data['Modified At'].notnull()

# %%
data['from_affiliation'] = data['Affiliated Channel'].notnull()

# %% [markdown]
# # Remove pointless cols

# %%
data = data.drop(columns=['Booked At', 'Room', 'Guests', 'Modified At', 'Affiliated Channel'])

# %%
data.head()
# Out:
#   Reservation ID      Channel Cancelled At   Check-In  Check-Out  Adults  \
# 0     2468606756  Booking.com          NaT 2022-01-02 2022-01-03       2
# 1     3404160971  Booking.com          NaT 2022-01-03 2022-01-05       2
# 2     3545920362  Booking.com          NaT 2022-01-03 2022-01-09       1
# 3     3807966157  Booking.com          NaT 2022-01-03 2022-01-06       2
# 4     2769935846  Booking.com          NaT 2022-01-03 2022-01-08       2
#
#    Children  Infants  days_ahead  discounted  stay  canceled_after_booking  \
# 0       NaN      NaN           1           1     1                     NaN
# 1       NaN      NaN           1           1     2                     NaN
# 2       NaN      NaN           0           0     6                     NaN
# 3       NaN      NaN           0           0     3                     NaN
# 4       1.0      NaN           2           0     5                     NaN
#
#    modified  from_affiliation
# 0     False             False
# 1     False             False
# 2     False             False
# 3     False             False
# 4     False             False

# %%
# Out:
# array([                          'NaT', '2022-01-06T00:00:00.000000000',
#        '2022-01-02T00:00:00.000000000', '2022-01-22T00:00:00.000000000',
#        '2022-01-18T00:00:00.000000000', '2022-01-25T00:00:00.000000000',
#        '2022-01-31T00:00:00.000000000', '2022-01-20T00:00:00.000000000',
#        '2022-01-24T00:00:00.000000000', '2022-03-05T00:00:00.000000000',
#        '2022-01-11T00:00:00.000000000', '2022-02-15T00:00:00.000000000',
#        '2022-04-08T00:00:00.000000000', '2022-01-10T00:00:00.000000000',
#        '2022-04-21T00:00:00.000000000', '2022-03-06T00:00:00.000000000',
#        '2022-04-25T00:00:00.000000000', '2022-02-04T00:00:00.000000000',
#        '2022-01-27T00:00:00.000000000', '2022-01-21T00:00:00.000000000',
#        '2022-02-08T00:00:00.000000000', '2022-01-23T00:00:00.000000000',
#        '2022-02-22T00:00:00.000000000', '2022-02-14T00:00:00.000000000',
#        '2022-02-05T00:00:00.000000000', '2022-02-20T00:00:00.000000000',
#        '2022-01-28T00:00:00.000000000', '2022-01-26T00:00:00.000000000',
#        '2022-03-01T00:00:00.000000000', '2022-02-01T00:00:00.000000000',
#        '2022-02-17T00:00:00.000000000', '2022-05-03T00:00:00.000000000',
#        '2022-05-27T00:00:00.000000000', '2022-03-28T00:00:00.000000000',
#        '2022-06-01T00:00:00.000000000', '2022-02-27T00:00:00.000000000',
#        '2022-02-06T00:00:00.000000000', '2022-02-11T00:00:00.000000000',
#        '2022-02-09T00:00:00.000000000', '2022-02-16T00:00:00.000000000',
#        '2022-02-10T00:00:00.000000000', '2022-02-02T00:00:00.000000000',
#        '2022-04-01T00:00:00.000000000', '2022-02-21T00:00:00.000000000',
#        '2022-02-25T00:00:00.000000000', '2022-03-15T00:00:00.000000000',
#        '2022-03-29T00:00:00.000000000', '2022-02-19T00:00:00.000000000',
#        '2022-01-29T00:00:00.000000000', '2022-04-27T00:00:00.000000000',
#        '2022-02-03T00:00:00.000000000', '2022-05-01T00:00:00.000000000',
#        '2022-05-18T00:00:00.000000000', '2022-07-30T00:00:00.000000000',
#        '2022-02-23T00:00:00.000000000', '2022-02-12T00:00:00.000000000',
#        '2022-02-26T00:00:00.000000000', '2022-03-22T00:00:00.000000000',
#        '2022-04-06T00:00:00.000000000', '2022-03-08T00:00:00.000000000',
#        '2022-02-13T00:00:00.000000000', '2022-04-02T00:00:00.000000000',
#        '2022-06-02T00:00:00.000000000', '2022-06-28T00:00:00.000000000',
#        '2022-05-12T00:00:00.000000000', '2022-03-10T00:00:00.000000000',
#        '2022-02-24T00:00:00.000000000', '2022-02-18T00:00:00.000000000',
#        '2022-02-28T00:00:00.000000000', '2022-04-12T00:00:00.000000000',
#        '2022-04-11T00:00:00.000000000', '2022-03-18T00:00:00.000000000',
#        '2022-04-10T00:00:00.000000000', '2022-06-09T00:00:00.000000000',
#        '2022-03-09T00:00:00.000000000', '2022-04-03T00:00:00.000000000',
#        '2022-04-16T00:00:00.000000000', '2022-07-31T00:00:00.000000000',
#        '2022-03-12T00:00:00.000000000', '2022-03-16T00:00:00.000000000',
#        '2022-03-13T00:00:00.000000000', '2022-03-02T00:00:00.000000000',
#        '2022-03-31T00:00:00.000000000', '2022-03-20T00:00:00.000000000',
#        '2022-03-24T00:00:00.000000000', '2022-05-20T00:00:00.000000000',
#        '2022-03-23T00:00:00.000000000', '2022-05-22T00:00:00.000000000',
#        '2022-04-29T00:00:00.000000000', '2022-04-05T00:00:00.000000000',
#        '2022-03-04T00:00:00.000000000', '2022-06-13T00:00:00.000000000',
#        '2022-06-15T00:00:00.000000000', '2022-07-23T00:00:00.000000000',
#        '2022-03-17T00:00:00.000000000', '2022-04-18T00:00:00.000000000',
#        '2022-06-05T00:00:00.000000000', '2022-03-21T00:00:00.000000000',
#        '2022-07-20T00:00:00.000000000', '2022-06-03T00:00:00.000000000',
#        '2022-08-16T00:00:00.000000000', '2022-04-28T00:00:00.000000000',
#        '2022-04-07T00:00:00.000000000', '2022-05-07T00:00:00.000000000',
#        '2022-05-26T00:00:00.000000000', '2022-05-31T00:00:00.000000000',
#        '2022-05-23T00:00:00.000000000', '2022-04-14T00:00:00.000000000',
#        '2022-04-17T00:00:00.000000000', '2022-04-20T00:00:00.000000000',
#        '2022-04-22T00:00:00.000000000', '2022-05-02T00:00:00.000000000',
#        '2022-04-23T00:00:00.000000000', '2022-05-15T00:00:00.000000000',
#        '2022-05-14T00:00:00.000000000', '2022-06-12T00:00:00.000000000',
#        '2022-06-22T00:00:00.000000000', '2022-05-11T00:00:00.000000000',
#        '2022-04-15T00:00:00.000000000', '2022-06-29T00:00:00.000000000',
#        '2022-04-19T00:00:00.000000000', '2022-04-24T00:00:00.000000000',
#        '2022-05-17T00:00:00.000000000', '2022-04-26T00:00:00.000000000',
#        '2022-05-29T00:00:00.000000000', '2022-06-08T00:00:00.000000000',
#        '2022-06-20T00:00:00.000000000', '2022-07-01T00:00:00.000000000',
#        '2022-05-04T00:00:00.000000000', '2022-06-21T00:00:00.000000000',
#        '2022-05-05T00:00:00.000000000', '2022-07-29T00:00:00.000000000',
#        '2022-05-19T00:00:00.000000000', '2022-07-26T00:00:00.000000000',
#        '2022-05-06T00:00:00.000000000', '2022-05-09T00:00:00.000000000',
#        '2022-05-25T00:00:00.000000000', '2022-05-08T00:00:00.000000000',
#        '2022-06-14T00:00:00.000000000', '2022-08-04T00:00:00.000000000',
#        '2022-07-18T00:00:00.000000000', '2022-07-02T00:00:00.000000000',
#        '2022-05-21T00:00:00.000000000', '2022-05-24T00:00:00.000000000',
#        '2022-06-17T00:00:00.000000000', '2022-08-02T00:00:00.000000000',
#        '2022-08-15T00:00:00.000000000', '2022-07-08T00:00:00.000000000',
#        '2022-06-04T00:00:00.000000000', '2022-05-30T00:00:00.000000000',
#        '2022-06-23T00:00:00.000000000', '2022-07-17T00:00:00.000000000',
#        '2022-08-10T00:00:00.000000000', '2022-07-21T00:00:00.000000000',
#        '2022-06-07T00:00:00.000000000', '2022-07-25T00:00:00.000000000',
#        '2022-06-18T00:00:00.000000000', '2022-06-16T00:00:00.000000000',
#        '2022-07-06T00:00:00.000000000', '2022-07-22T00:00:00.000000000',
#        '2022-06-25T00:00:00.000000000', '2022-07-10T00:00:00.000000000',
#        '2022-08-17T00:00:00.000000000', '2022-08-19T00:00:00.000000000',
#        '2022-07-16T00:00:00.000000000', '2022-07-03T00:00:00.000000000',
#        '2022-07-11T00:00:00.000000000', '2022-08-25T00:00:00.000000000',
#        '2022-07-28T00:00:00.000000000', '2022-06-30T00:00:00.000000000',
#        '2022-07-05T00:00:00.000000000', '2022-07-13T00:00:00.000000000',
#        '2022-07-12T00:00:00.000000000', '2022-08-06T00:00:00.000000000',
#        '2022-08-07T00:00:00.000000000', '2022-07-19T00:00:00.000000000',
#        '2022-07-15T00:00:00.000000000', '2022-08-14T00:00:00.000000000',
#        '2022-08-11T00:00:00.000000000', '2022-08-23T00:00:00.000000000',
#        '2022-08-28T00:00:00.000000000', '2022-07-14T00:00:00.000000000',
#        '2022-08-20T00:00:00.000000000', '2022-08-09T00:00:00.000000000',
#        '2022-08-05T00:00:00.000000000', '2022-08-08T00:00:00.000000000',
#        '2022-08-13T00:00:00.000000000', '2022-07-24T00:00:00.000000000',
#        '2022-08-03T00:00:00.000000000', '2022-08-27T00:00:00.000000000',
#        '2022-07-27T00:00:00.000000000', '2022-08-21T00:00:00.000000000',
#        '2022-08-24T00:00:00.000000000', '2022-08-26T00:00:00.000000000',
#        '2022-08-29T00:00:00.000000000', '2022-08-30T00:00:00.000000000',
#        '2022-08-22T00:00:00.000000000'], dtype='datetime64[ns]')
